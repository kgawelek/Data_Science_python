# %%
import pandas as pd
import numpy as np

# %%
fuel = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=['Year','Make','Model','Range (FT1)','City Range (FT1)'])

# %%
fuel.set_index(['Year','Make','Model'], inplace=True)

# %%
fuel.sort_index(inplace=True)

# %%
fuel.head()
# Out:
#                                    Range (FT1)  City Range (FT1)
# Year Make       Model
# 1984 AM General DJ Po Vehicle 2WD          0.0               0.0
#                 DJ Po Vehicle 2WD          0.0               0.0
#                 FJ8c Post Office           0.0               0.0
#                 FJ8c Post Office           0.0               0.0
#      Alfa Romeo GT V6 2.5                  0.0               0.0

# %%
fuel.loc[(1984)]
# Out:
#                                                    Range (FT1)  \
# Make                        Model
# AM General                  DJ Po Vehicle 2WD              0.0
#                             DJ Po Vehicle 2WD              0.0
#                             FJ8c Post Office               0.0
#                             FJ8c Post Office               0.0
# Alfa Romeo                  GT V6 2.5                      0.0
#                             GT V6 2.5                      0.0
#                             Spider Veloce 2000             0.0
#                             Spider Veloce 2000             0.0
# American Motors Corporation Eagle 4WD                      0.0
#                             Eagle 4WD                      0.0
#                             Eagle 4WD                      0.0
#                             Eagle 4WD                      0.0
#                             Eagle 4WD                      0.0
# ...

# %%
fuel.loc[(1984, 'Alfa Romeo')]
# Out:
#                     Range (FT1)  City Range (FT1)
# Model
# GT V6 2.5                   0.0               0.0
# GT V6 2.5                   0.0               0.0
# Spider Veloce 2000          0.0               0.0
# Spider Veloce 2000          0.0               0.0

# %%
fuel.loc[(1984,'Alfa Romeo', 'Spider Veloce 2000')]
# Out:
#                                     Range (FT1)  City Range (FT1)
# Year Make       Model
# 1984 Alfa Romeo Spider Veloce 2000          0.0               0.0
#                 Spider Veloce 2000          0.0               0.0

# %%
fuel.loc[(1984,'Alfa Romeo', 'Spider Veloce 2000'), 'City Range (FT1)']
# Out:
# Year  Make        Model
# 1984  Alfa Romeo  Spider Veloce 2000    0.0
#                   Spider Veloce 2000    0.0
# Name: City Range (FT1), dtype: float64

# %%
fuel = fuel.transpose()

# %%
fuel
# Out:
# Year                          1984                                     \
# Make                    AM General
# Model            DJ Po Vehicle 2WD DJ Po Vehicle 2WD FJ8c Post Office
# Range (FT1)                    0.0               0.0              0.0
# City Range (FT1)               0.0               0.0              0.0
#
# Year                                                                       \
# Make                              Alfa Romeo
# Model            FJ8c Post Office  GT V6 2.5 GT V6 2.5 Spider Veloce 2000
# Range (FT1)                   0.0        0.0       0.0                0.0
# City Range (FT1)              0.0        0.0       0.0                0.0
#
# Year                                                                       \
# Make                                American Motors Corporation
# Model            Spider Veloce 2000                   Eagle 4WD Eagle 4WD
# Range (FT1)                     0.0                         0.0       0.0
# ...

# %%
fuel.loc['Range (FT1)']
# Out:
# Year  Make                         Model
# 1984  AM General                   DJ Po Vehicle 2WD      0.0
#                                    DJ Po Vehicle 2WD      0.0
#                                    FJ8c Post Office       0.0
#                                    FJ8c Post Office       0.0
#       Alfa Romeo                   GT V6 2.5              0.0
#                                    GT V6 2.5              0.0
#                                    Spider Veloce 2000     0.0
#                                    Spider Veloce 2000     0.0
#       American Motors Corporation  Eagle 4WD              0.0
#                                    Eagle 4WD              0.0
#                                    Eagle 4WD              0.0
#                                    Eagle 4WD              0.0
#                                    Eagle 4WD              0.0
#                                    Eagle 4WD              0.0
# ...

# %%
fuel.loc[('Range (FT1)'), 1984]
# Out:
# Make                         Model
# AM General                   DJ Po Vehicle 2WD        0.0
#                              DJ Po Vehicle 2WD        0.0
#                              FJ8c Post Office         0.0
#                              FJ8c Post Office         0.0
# Alfa Romeo                   GT V6 2.5                0.0
#                              GT V6 2.5                0.0
#                              Spider Veloce 2000       0.0
#                              Spider Veloce 2000       0.0
# American Motors Corporation  Eagle 4WD                0.0
#                              Eagle 4WD                0.0
#                              Eagle 4WD                0.0
#                              Eagle 4WD                0.0
#                              Eagle 4WD                0.0
#                              Eagle 4WD                0.0
#                              Eagle 4WD                0.0
#                              Eagle 4WD                0.0
# ...

# %%
fuel.loc['Range (FT1)',  (1984,'Alfa Romeo')]
# Out:
# Model
# GT V6 2.5             0.0
# GT V6 2.5             0.0
# Spider Veloce 2000    0.0
# Spider Veloce 2000    0.0
# Name: Range (FT1), dtype: float64

# %%
fuel.loc['Range (FT1)',  (1984,'Alfa Romeo', 'Spider Veloce 2000')]
# Out:
# Year  Make        Model
# 1984  Alfa Romeo  Spider Veloce 2000    0.0
#                   Spider Veloce 2000    0.0
# Name: Range (FT1), dtype: float64

# %%
fuel = fuel.transpose()

# %%
fuel.head()
# Out:
#                                    Range (FT1)  City Range (FT1)
# Year Make       Model
# 1984 AM General DJ Po Vehicle 2WD          0.0               0.0
#                 DJ Po Vehicle 2WD          0.0               0.0
#                 FJ8c Post Office           0.0               0.0
#                 FJ8c Post Office           0.0               0.0
#      Alfa Romeo GT V6 2.5                  0.0               0.0

# %%
fuel = fuel.swaplevel('Year', 'Make')

# %%
fuel.head()
# Out:
#                                    Range (FT1)  City Range (FT1)
# Make       Year Model
# AM General 1984 DJ Po Vehicle 2WD          0.0               0.0
#                 DJ Po Vehicle 2WD          0.0               0.0
#                 FJ8c Post Office           0.0               0.0
#                 FJ8c Post Office           0.0               0.0
# Alfa Romeo 1984 GT V6 2.5                  0.0               0.0

# %%
fuel.sort_index(inplace=True)

# %%
fuel.head()
# Out:
#                                      Range (FT1)  City Range (FT1)
# Make       Year Model
# AM General 1984 DJ Po Vehicle 2WD            0.0               0.0
#                 DJ Po Vehicle 2WD            0.0               0.0
#                 FJ8c Post Office             0.0               0.0
#                 FJ8c Post Office             0.0               0.0
#            1985 Post Office DJ5 2WD          0.0               0.0

# %%
fuel.loc['Alfa Romeo', 1984, 'Spider Veloce 2000']
# Out:
#                                     Range (FT1)  City Range (FT1)
# Make       Year Model
# Alfa Romeo 1984 Spider Veloce 2000          0.0               0.0
#                 Spider Veloce 2000          0.0               0.0

# %%
fuel = fuel.swaplevel('Year', 'Model')

# %%
fuel.sort_index(inplace=True)
fuel.head()
# Out:
#                                      Range (FT1)  City Range (FT1)
# Make       Model               Year
# AM General DJ Po Vehicle 2WD   1984          0.0               0.0
#                                1984          0.0               0.0
#            FJ8c Post Office    1984          0.0               0.0
#                                1984          0.0               0.0
#            Post Office DJ5 2WD 1985          0.0               0.0

# %%
fuel.loc['Alfa Romeo', 'Spider Veloce 2000', 1984]
# Out:
#                                     Range (FT1)  City Range (FT1)
# Make       Model              Year
# Alfa Romeo Spider Veloce 2000 1984          0.0               0.0
#                               1984          0.0               0.0

# %%
fuel = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=['Year','Make','Model','Range (FT1)','City Range (FT1)'])

# %%
fuel.drop_duplicates(subset=['Year', 'Make', 'Model'], inplace=True)

# %%
fuel.dropna(inplace=True)

# %%
fuel.set_index(['Year', 'Make', 'Model'], inplace=True)

# %%
fuel.head()
# Out:
#                                                      Range (FT1)  \
# Year Make                        Model
# 1984 Alfa Romeo                  GT V6 2.5                   0.0
#                                  Spider Veloce 2000          0.0
#      AM General                  DJ Po Vehicle 2WD           0.0
#                                  FJ8c Post Office            0.0
#      American Motors Corporation Eagle 4WD                   0.0
#
#                                                      City Range (FT1)
# Year Make                        Model
# 1984 Alfa Romeo                  GT V6 2.5                        0.0
#                                  Spider Veloce 2000               0.0
#      AM General                  DJ Po Vehicle 2WD                0.0
#                                  FJ8c Post Office                 0.0
#      American Motors Corporation Eagle 4WD                        0.0

# %%
fuel.stack().head()
# Out:
# Year  Make        Model
# 1984  Alfa Romeo  GT V6 2.5           Range (FT1)         0.0
#                                       City Range (FT1)    0.0
#                   Spider Veloce 2000  Range (FT1)         0.0
#                                       City Range (FT1)    0.0
#       AM General  DJ Po Vehicle 2WD   Range (FT1)         0.0
# dtype: float64

# %%
fuel.stack().to_frame().head()
# Out:
#                                                        0
# Year Make       Model
# 1984 Alfa Romeo GT V6 2.5          Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#                 Spider Veloce 2000 Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#      AM General DJ Po Vehicle 2WD  Range (FT1)       0.0

# %%
fuel.unstack(level='Model').head()
# Out:
#                                  Range (FT1)                             \
# Model                                 09-Mar 09-May 1-Ton Truck 2WD 100
# Year Make
# 1984 AM General                          NaN    NaN             NaN NaN
#      Alfa Romeo                          NaN    NaN             NaN NaN
#      American Motors Corporation         NaN    NaN             NaN NaN
#      Aston Martin                        NaN    NaN             NaN NaN
#      Audi                                NaN    NaN             NaN NaN
#
#                                                                                \
# Model                            100 Wagon 100 quattro 100 quattro Wagon 1000
# Year Make
# 1984 AM General                        NaN         NaN               NaN  NaN
#      Alfa Romeo                        NaN         NaN               NaN  NaN
#      American Motors Corporation       NaN         NaN               NaN  NaN
# ...

# %%
fuel.unstack(level='Year').head()
# Out:
#                                      Range (FT1)                           \
# Year                                        1984 1985 1986 1987 1988 1989
# Make             Model
# AM General       DJ Po Vehicle 2WD           0.0  NaN  NaN  NaN  NaN  NaN
#                  FJ8c Post Office            0.0  NaN  NaN  NaN  NaN  NaN
#                  Post Office DJ5 2WD         NaN  0.0  NaN  NaN  NaN  NaN
#                  Post Office DJ8 2WD         NaN  0.0  NaN  NaN  NaN  NaN
# ASC Incorporated GNX                         NaN  NaN  NaN  0.0  NaN  NaN
#
#                                                          ...   \
# Year                                 1990 1991 1992 1993 ...
# Make             Model                                   ...
# AM General       DJ Po Vehicle 2WD    NaN  NaN  NaN  NaN ...
#                  FJ8c Post Office     NaN  NaN  NaN  NaN ...
#                  Post Office DJ5 2WD  NaN  NaN  NaN  NaN ...
# ...

# %%
fuel.stack().unstack('Year').head()
# Out:
# Year                                             1984  1985  1986  1987  1988  \
# Make       Model
# AM General DJ Po Vehicle 2WD   Range (FT1)        0.0   NaN   NaN   NaN   NaN
#                                City Range (FT1)   0.0   NaN   NaN   NaN   NaN
#            FJ8c Post Office    Range (FT1)        0.0   NaN   NaN   NaN   NaN
#                                City Range (FT1)   0.0   NaN   NaN   NaN   NaN
#            Post Office DJ5 2WD Range (FT1)        NaN   0.0   NaN   NaN   NaN
#
# Year                                             1989  1990  1991  1992  1993  \
# Make       Model
# AM General DJ Po Vehicle 2WD   Range (FT1)        NaN   NaN   NaN   NaN   NaN
#                                City Range (FT1)   NaN   NaN   NaN   NaN   NaN
#            FJ8c Post Office    Range (FT1)        NaN   NaN   NaN   NaN   NaN
#                                City Range (FT1)   NaN   NaN   NaN   NaN   NaN
# ...

# %%
fuel.stack().unstack('Make').head()
# Out:
# Make                                       AM General  ASC Incorporated  \
# Year Model
# 1984 1000                Range (FT1)              NaN               NaN
#                          City Range (FT1)         NaN               NaN
#      18i                 Range (FT1)              NaN               NaN
#                          City Range (FT1)         NaN               NaN
#      190 D 2.2/190 E 2.3 Range (FT1)              NaN               NaN
#
# Make                                       Acura  Alfa Romeo  \
# Year Model
# 1984 1000                Range (FT1)         NaN         NaN
#                          City Range (FT1)    NaN         NaN
#      18i                 Range (FT1)         NaN         NaN
#                          City Range (FT1)    NaN         NaN
#      190 D 2.2/190 E 2.3 Range (FT1)         NaN         NaN
#
# Make                                       American Motors Corporation  \
# Year Model
# ...

# %%
fuel.stack().unstack(['Year', 'Make']).head()
# Out:
# Year                                   1984             \
# Make                             Alfa Romeo AM General
# Model
# 09-Mar          Range (FT1)             NaN        NaN
#                 City Range (FT1)        NaN        NaN
# 09-May          Range (FT1)             NaN        NaN
#                 City Range (FT1)        NaN        NaN
# 1-Ton Truck 2WD Range (FT1)             NaN        NaN
#
# Year                                                                       \
# Make                             American Motors Corporation Aston Martin
# Model
# 09-Mar          Range (FT1)                              NaN          NaN
#                 City Range (FT1)                         NaN          NaN
# 09-May          Range (FT1)                              NaN          NaN
#                 City Range (FT1)                         NaN          NaN
# 1-Ton Truck 2WD Range (FT1)                              NaN          NaN
#
# ...

# %%
fuel.stack().unstack(['Make', 'Year']).sort_index(axis='columns').head()
# Out:
# Make                             AM General      ASC Incorporated Acura       \
# Year                                   1984 1985             1987  1986 1987
# Model
# 09-Mar          Range (FT1)             NaN  NaN              NaN   NaN  NaN
#                 City Range (FT1)        NaN  NaN              NaN   NaN  NaN
# 09-May          Range (FT1)             NaN  NaN              NaN   NaN  NaN
#                 City Range (FT1)        NaN  NaN              NaN   NaN  NaN
# 1-Ton Truck 2WD Range (FT1)             NaN  NaN              NaN   NaN  NaN
#
# Make                                                      ...   \
# Year                             1988 1989 1990 1991 1992 ...
# Model                                                     ...
# 09-Mar          Range (FT1)       NaN  NaN  NaN  NaN  NaN ...
#                 City Range (FT1)  NaN  NaN  NaN  NaN  NaN ...
# 09-May          Range (FT1)       NaN  NaN  NaN  NaN  NaN ...
# ...
