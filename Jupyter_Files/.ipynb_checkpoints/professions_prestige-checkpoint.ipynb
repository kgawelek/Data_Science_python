# %%
import pandas as pd
import numpy as np
professions = pd.read_csv('../course-files/prestige.csv', index_col='name')

# %%
professions
# Out:
#                            education  income  women  prestige  census  type
# name
# gov.administrators             13.11   12351  11.16      68.8    1113  prof
# general.managers               12.26   25879   4.02      69.1    1130  prof
# accountants                    12.77    9271  15.70      63.4    1171  prof
# purchasing.officers            11.42    8865   9.11      56.8    1175  prof
# chemists                       14.62    8403  11.68      73.5    2111  prof
# physicists                     15.64   11030   5.13      77.6    2113  prof
# biologists                     15.09    8258  25.65      72.6    2133  prof
# architects                     15.44   14163   2.69      78.1    2141  prof
# civil.engineers                14.52   11377   1.03      73.1    2143  prof
# mining.engineers               14.64   11023   0.94      68.8    2153  prof
# surveyors                      12.39    5902   1.91      62.0    2161  prof
# ...

# %%
professionsOriginal = professions.copy()

# %%
professions.rename(columns={'women': 'women_percentage', 'prestige': 'prestige_indicator'})
# Out:
#                            education  income  women_percentage  \
# name
# gov.administrators             13.11   12351             11.16
# general.managers               12.26   25879              4.02
# accountants                    12.77    9271             15.70
# purchasing.officers            11.42    8865              9.11
# chemists                       14.62    8403             11.68
# physicists                     15.64   11030              5.13
# biologists                     15.09    8258             25.65
# architects                     15.44   14163              2.69
# civil.engineers                14.52   11377              1.03
# mining.engineers               14.64   11023              0.94
# surveyors                      12.39    5902              1.91
# draughtsmen                    12.30    7059              7.83
# computer.programers            13.83    8425             15.33
# economists                     14.44    8049             57.31
# ...

# %%
professions.rename(index={'general.managers': 'managers', 'accountants': 'bookkeepers'})
# Out:
#                            education  income  women  prestige  census  type
# name
# gov.administrators             13.11   12351  11.16      68.8    1113  prof
# managers                       12.26   25879   4.02      69.1    1130  prof
# bookkeepers                    12.77    9271  15.70      63.4    1171  prof
# purchasing.officers            11.42    8865   9.11      56.8    1175  prof
# chemists                       14.62    8403  11.68      73.5    2111  prof
# physicists                     15.64   11030   5.13      77.6    2113  prof
# biologists                     15.09    8258  25.65      72.6    2133  prof
# architects                     15.44   14163   2.69      78.1    2141  prof
# civil.engineers                14.52   11377   1.03      73.1    2143  prof
# mining.engineers               14.64   11023   0.94      68.8    2153  prof
# surveyors                      12.39    5902   1.91      62.0    2161  prof
# ...

# %%
professionsOriginal.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof

# %%
professions.loc['chemists', 'type'] = 'scientist'

# %%
professions.head()
# Out:
#                      education  income  women  prestige  census       type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113       prof
# general.managers         12.26   25879   4.02      69.1    1130       prof
# accountants              12.77    9271  15.70      63.4    1171       prof
# purchasing.officers      11.42    8865   9.11      56.8    1175       prof
# chemists                 14.62    8403  11.68      73.5    2111  scientist

# %%
is_scientist = professions.type == 'scientist'

# %%
professions.loc[is_scientist, 'prestige'] = 90

# %%
professions.head()
# Out:
#                      education  income  women  prestige  census       type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113       prof
# general.managers         12.26   25879   4.02      69.1    1130       prof
# accountants              12.77    9271  15.70      63.4    1171       prof
# purchasing.officers      11.42    8865   9.11      56.8    1175       prof
# chemists                 14.62    8403  11.68      90.0    2111  scientist

# %%
professions.loc[is_scientist, 'income'] *= 1.5

# %%
professions[is_scientist]
# Out:
#           education   income  women  prestige  census       type
# name
# chemists      14.62  12604.5  11.68      90.0    2111  scientist

# %%
professions = pd.read_csv('../course-files/prestige.csv')
dict = {'name': 'data scientist', 'income': np.NaN, 'women': np.NaN, 'prestige': np.NaN, 'census': np.NaN, 'type': np.NaN}

# %%
dict
# Out:
# {'name': 'data scientist',
#  'income': nan,
#  'women': nan,
#  'prestige': nan,
#  'census': nan,
#  'type': nan}

# %%
professions = professions.append(dict, ignore_index=True)

# %%
professions.tail()
# Out:
#                name  education  income  women  prestige  census type
# 98     taxi.drivers       7.93  4224.0   3.59      25.1  9173.0   bc
# 99     longshoremen       8.37  4753.0   0.00      26.1  9313.0   bc
# 100     typesetters      10.00  6462.0  13.58      42.2  9511.0   bc
# 101     bookbinders       8.55  3617.0  70.87      35.2  9517.0   bc
# 102  data scientist        NaN     NaN    NaN       NaN     NaN  NaN

# %%
taxi = professions.query('name == "taxi.drivers"')

# %%
taxi
# Out:
#             name  education  income  women  prestige  census type
# 98  taxi.drivers       7.93  4224.0   3.59      25.1  9173.0   bc

# %%
professions.drop(98, inplace=True)

# %%
professions.tail()
# Out:
#                name  education  income  women  prestige  census type
# 97      bus.drivers       7.58  5562.0   9.47      35.9  9171.0   bc
# 99     longshoremen       8.37  4753.0   0.00      26.1  9313.0   bc
# 100     typesetters      10.00  6462.0  13.58      42.2  9511.0   bc
# 101     bookbinders       8.55  3617.0  70.87      35.2  9517.0   bc
# 102  data scientist        NaN     NaN    NaN       NaN     NaN  NaN

# %%
professions = professions.append(taxi)

# %%
professions.tail()
# Out:
#                name  education  income  women  prestige  census type
# 99     longshoremen       8.37  4753.0   0.00      26.1  9313.0   bc
# 100     typesetters      10.00  6462.0  13.58      42.2  9511.0   bc
# 101     bookbinders       8.55  3617.0  70.87      35.2  9517.0   bc
# 102  data scientist        NaN     NaN    NaN       NaN     NaN  NaN
# 98     taxi.drivers       7.93  4224.0   3.59      25.1  9173.0   bc

# %%
del professions['census']

# %%
professions.drop(columns='type', inplace=True)

# %%
professions.head()
# Out:
#                   name  education   income  women  prestige
# 0   gov.administrators      13.11  12351.0  11.16      68.8
# 1     general.managers      12.26  25879.0   4.02      69.1
# 2          accountants      12.77   9271.0  15.70      63.4
# 3  purchasing.officers      11.42   8865.0   9.11      56.8
# 4             chemists      14.62   8403.0  11.68      73.5
