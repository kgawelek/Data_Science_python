# %%
import pandas as pd

# %%
fuels = pd.read_csv('../course-files/fuel.csv')
# Out:
# /home/kgawelek/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (16,62,64,65,66,78) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fuels['Fuel Type 1'].value_counts()
# Out:
# Regular Gasoline     23232
# Premium Gasoline      7411
# Diesel                 936
# Natural Gas             55
# Electricity             33
# Midgrade Gasoline       16
# Name: Fuel Type 1, dtype: int64

# %%
fuels = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=[ 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'])

# %%
fuels = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=[ 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'], index_col='Vehicle ID')

# %%
fuels
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# ...          ...         ...                 ...                          ...
# 32060       2012  Mitsubishi              Lancer                 Compact Cars
# 32063       2012  Mitsubishi          Lancer AWD                 Compact Cars
# 32065       2012  Mitsubishi    Lancer Evolution                 Compact Cars
# 32064       2012  Mitsubishi    Lancer Evolution                 Compact Cars
# 32106       2012   Mitsubish                 NaN                          NaN
#
# ...

# %%
fuels = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=[ 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'])

# %%
fuels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31684 entries, 0 to 31683
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Vehicle ID          31684 non-null  int64
#  1   Year                31684 non-null  int64
#  2   Make                31684 non-null  object
#  3   Model               31683 non-null  object
#  4   Class               31683 non-null  object
#  5   Fuel Type           31683 non-null  object
#  6   Combined MPG (FT1)  31683 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.7+ MB

# %%
fuels.dtypes.value_counts()
# Out:
# object     4
# int64      2
# float64    1
# dtype: int64

# %%
fuels.dtypes
# Out:
# Vehicle ID              int64
# Year                    int64
# Make                   object
# Model                  object
# Class                  object
# Fuel Type              object
# Combined MPG (FT1)    float64
# dtype: object

# %%
fuels['Make'].value_counts().head(10)
# Out:
# Chevrolet        3389
# Ford             2721
# Dodge            2361
# GMC              2174
# Toyota           1599
# BMW              1180
# Nissan           1082
# Mercedes-Benz     948
# Mitsubishi        937
# Pontiac           893
# Name: Make, dtype: int64

# %%
fuels.count
# Out:
# <bound method DataFrame.count of        Vehicle ID  Year        Make               Model  \
# 0           26587  1984  Alfa Romeo           GT V6 2.5
# 1           27705  1984  Alfa Romeo           GT V6 2.5
# 2           26561  1984  Alfa Romeo  Spider Veloce 2000
# 3           27681  1984  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  AM General   DJ Po Vehicle 2WD
# ...           ...   ...         ...                 ...
# 31679       32060  2012  Mitsubishi              Lancer
# 31680       32063  2012  Mitsubishi          Lancer AWD
# 31681       32065  2012  Mitsubishi    Lancer Evolution
# 31682       32064  2012  Mitsubishi    Lancer Evolution
# 31683       32106  2012   Mitsubish                 NaN
#
#                              Class Fuel Type  Combined MPG (FT1)
# 0                 Minicompact Cars   Regular                20.0
# 1                 Minicompact Cars   Regular                20.0
# ...

# %%
len(fuels)
# Out:
# 31684

# %%
fuels.Make
# Out:
# 0        Alfa Romeo
# 1        Alfa Romeo
# 2        Alfa Romeo
# 3        Alfa Romeo
# 4        AM General
#             ...
# 31679    Mitsubishi
# 31680    Mitsubishi
# 31681    Mitsubishi
# 31682    Mitsubishi
# 31683     Mitsubish
# Name: Make, Length: 31684, dtype: object

# %%
fuels.Make.value_counts().head()
# Out:
# Chevrolet    3389
# Ford         2721
# Dodge        2361
# GMC          2174
# Toyota       1599
# Name: Make, dtype: int64

# %%
fuels.loc[1873, 'Vehicle ID']
# Out:
# 26784

# %%
fuels.loc[fuels.loc[1873, 'Vehicle ID']].loc['Combined MPG (FT1)']
# Out:
# 29.0

# %%
fuels['Combined MPG (FT1)'].max()
# Out:
# 112.0

# %%
fuels['Combined MPG (FT1)'].idxmax()
# Out:
# 31674

# %%
fuels.loc[31674]
# Out:
# Vehicle ID                      31673
# Year                             2012
# Make                       Mitsubishi
# Model                          i-MiEV
# Class                 Subcompact Cars
# Fuel Type                 Electricity
# Combined MPG (FT1)                112
# Name: 31674, dtype: object

# %%
fuels.loc[fuels['Combined MPG (FT1)'].idxmax()] # to samo co wyzej, tylko w jednym poleceniu
# Out:
# Vehicle ID                      31673
# Year                             2012
# Make                       Mitsubishi
# Model                          i-MiEV
# Class                 Subcompact Cars
# Fuel Type                 Electricity
# Combined MPG (FT1)                112
# Name: 31674, dtype: object

# %%
fuels = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=[ 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'], index_col='Vehicle ID')
short_fuel = fuels[['Make', 'Model']]

# %%
short_fuel.head()
# Out:
#                   Make               Model
# Vehicle ID
# 26587       Alfa Romeo           GT V6 2.5
# 27705       Alfa Romeo           GT V6 2.5
# 26561       Alfa Romeo  Spider Veloce 2000
# 27681       Alfa Romeo  Spider Veloce 2000
# 27550       AM General   DJ Po Vehicle 2WD

# %%
fuels['Combine KPL'] = fuels['Combined MPG (FT1)']* 1.609 / 3.78

# %%
fuels.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)  Combine KPL
# Vehicle ID
# 26587        Regular                20.0     8.513228
# 27705        Regular                20.0     8.513228
# 26561        Regular                21.0     8.938889
# 27681        Regular                21.0     8.938889
# 27550        Regular                17.0     7.236243

# %%
fuels.insert(loc=5, column='liters per km', value = 100 / fuels['Combine KPL'])
fuels.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  liters per km  Combined MPG (FT1)  Combine KPL
# Vehicle ID
# 26587        Regular      11.746426                20.0     8.513228
# 27705        Regular      11.746426                20.0     8.513228
# 26561        Regular      11.187073                21.0     8.938889
# 27681        Regular      11.187073                21.0     8.938889
# 27550        Regular      13.819325                17.0     7.236243

# %%
fuels.loc[fuels['liters per km'].idxmax()]
# Out:
# Year                         1986
# Make                  Lamborghini
# Model                    Countach
# Class                 Two Seaters
# Fuel Type                 Premium
# liters per km             33.5612
# Combined MPG (FT1)              7
# Combine KPL               2.97963
# Name: 1711, dtype: object

# %%
del fuels['Combined MPG (FT1)']

# %%
fuels.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  liters per km  Combine KPL
# Vehicle ID
# 26587        Regular      11.746426     8.513228
# 27705        Regular      11.746426     8.513228
# 26561        Regular      11.187073     8.938889
# 27681        Regular      11.187073     8.938889
# 27550        Regular      13.819325     7.236243

# %%
fuels = fuels.drop(axis=1, columns=['Combine KPL'])

# %%
fuels.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  liters per km
# Vehicle ID
# 26587        Regular      11.746426
# 27705        Regular      11.746426
# 26561        Regular      11.187073
# 27681        Regular      11.187073
# 27550        Regular      13.819325

# %%
import numpy as np
fuels_v2 = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=[ 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'], index_col='Vehicle ID')

# %%
fuels_v2.loc[27705, 'Class'] = np.NaN
fuels_v2.loc[26561, 'Class'] = np.NaN
fuels_v2.loc[27550, 'Fuel Type'] = np.NaN

# %%
fuels_v2.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                          NaN
# 26561       1984  Alfa Romeo  Spider Veloce 2000                          NaN
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                21.0
# 27550            NaN                17.0

# %%
fuels_v2.dropna().head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 28426       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 27549       1984  AM General    FJ8c Post Office  Special Purpose Vehicle 2WD
# 28425       1984  AM General    FJ8c Post Office  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27681        Regular                21.0
# 28426        Regular                17.0
# 27549        Regular                13.0
# 28425        Regular                13.0

# %%
fuels_v2.dropna(axis=1)
# Out:
#             Year        Make
# Vehicle ID
# 26587       1984  Alfa Romeo
# 27705       1984  Alfa Romeo
# 26561       1984  Alfa Romeo
# 27681       1984  Alfa Romeo
# 27550       1984  AM General
# ...          ...         ...
# 32060       2012  Mitsubishi
# 32063       2012  Mitsubishi
# 32065       2012  Mitsubishi
# 32064       2012  Mitsubishi
# 32106       2012   Mitsubish
#
# [31684 rows x 2 columns]

# %%
fuels_v2.dropna(subset=['Class']).head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 28426       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 27549       1984  AM General    FJ8c Post Office  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27681        Regular                21.0
# 27550            NaN                17.0
# 28426        Regular                17.0
# 27549        Regular                13.0

# %%
fuels_v2.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                          NaN
# 26561       1984  Alfa Romeo  Spider Veloce 2000                          NaN
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                21.0
# 27550            NaN                17.0

# %%
fuels_v2.dropna(subset=['Class'], inplace=True)
fuels_v2.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 28426       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 27549       1984  AM General    FJ8c Post Office  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27681        Regular                21.0
# 27550            NaN                17.0
# 28426        Regular                17.0
# 27549        Regular                13.0

# %%
fuel_v3 = fuels_v2 # set for fillna() practicing

# %%
fuel_v3.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 28426       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 27549       1984  AM General    FJ8c Post Office  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27681        Regular                21.0
# 27550            NaN                17.0
# 28426        Regular                17.0
# 27549        Regular                13.0

# %%
fuel_v3.loc[27705, 'Class'] = np.NaN
fuel_v3.loc[26561, 'Class'] = np.NaN
fuel_v3.loc[27550, 'Fuel Type'] = np.NaN
fuel_v3.loc[27705, 'Combined MPG (FT1)'] = np.NaN
fuel_v3.loc[27681, 'Combined MPG (FT1)'] = np.NaN

# %%
fuel_v3.head()
# Out:
#               Year        Make               Model  \
# Vehicle ID
# 26587       1984.0  Alfa Romeo           GT V6 2.5
# 27681       1984.0  Alfa Romeo  Spider Veloce 2000
# 27550       1984.0  AM General   DJ Po Vehicle 2WD
# 28426       1984.0  AM General   DJ Po Vehicle 2WD
# 27549       1984.0  AM General    FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587                  Minicompact Cars   Regular                20.0
# 27681                       Two Seaters   Regular                 NaN
# 27550       Special Purpose Vehicle 2WD       NaN                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0

# %%
fuel_v3.fillna(-1).head()
# Out:
#               Year        Make               Model  \
# Vehicle ID
# 26587       1984.0  Alfa Romeo           GT V6 2.5
# 27681       1984.0  Alfa Romeo  Spider Veloce 2000
# 27550       1984.0  AM General   DJ Po Vehicle 2WD
# 28426       1984.0  AM General   DJ Po Vehicle 2WD
# 27549       1984.0  AM General    FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587                  Minicompact Cars   Regular                20.0
# 27681                       Two Seaters   Regular                -1.0
# 27550       Special Purpose Vehicle 2WD        -1                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0

# %%
replace_rules = {'Class': '---', 'Fuel Type': '---', 'Combined MPG (FT1)': -1}

# %%
fuel_v3.fillna(replace_rules).head()
# Out:
#               Year        Make               Model  \
# Vehicle ID
# 26587       1984.0  Alfa Romeo           GT V6 2.5
# 27681       1984.0  Alfa Romeo  Spider Veloce 2000
# 27550       1984.0  AM General   DJ Po Vehicle 2WD
# 28426       1984.0  AM General   DJ Po Vehicle 2WD
# 27549       1984.0  AM General    FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587                  Minicompact Cars   Regular                20.0
# 27681                       Two Seaters   Regular                -1.0
# 27550       Special Purpose Vehicle 2WD       ---                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0

# %%
avg_MPG = fuel_v3['Combined MPG (FT1)'].mean()

# %%
avg_MPG
# Out:
# 19.44412878787879

# %%
fuel_v3['Combined MPG (FT1)'].fillna(avg_MPG, inplace=True)

# %%
fuel_v3['Class'].fillna('?', inplace=True)
fuel_v3['Fuel Type'].fillna('?', inplace=True)

# %%
fuel_v3.head()
# Out:
#               Year        Make               Model  \
# Vehicle ID
# 26587       1984.0  Alfa Romeo           GT V6 2.5
# 27681       1984.0  Alfa Romeo  Spider Veloce 2000
# 27550       1984.0  AM General   DJ Po Vehicle 2WD
# 28426       1984.0  AM General   DJ Po Vehicle 2WD
# 27549       1984.0  AM General    FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587                  Minicompact Cars   Regular           20.000000
# 27681                       Two Seaters   Regular           19.444129
# 27550       Special Purpose Vehicle 2WD         ?           17.000000
# 28426       Special Purpose Vehicle 2WD   Regular           17.000000
# 27549       Special Purpose Vehicle 2WD   Regular           13.000000

# %%
fuel_v3.loc[27705, 'Class'] = np.NaN
fuel_v3.loc[26561, 'Class'] = np.NaN
fuel_v3.loc[27550, 'Fuel Type'] = np.NaN
fuel_v3.loc[27705, 'Combined MPG (FT1)'] = np.NaN
fuel_v3.loc[27681, 'Combined MPG (FT1)'] = np.NaN

# %%
fuel_v3['Combined MPG (FT1)'].fillna(method='ffill', inplace=True)

# %%
fuel_v3.head()
# Out:
#               Year        Make               Model  \
# Vehicle ID
# 26587       1984.0  Alfa Romeo           GT V6 2.5
# 27681       1984.0  Alfa Romeo  Spider Veloce 2000
# 27550       1984.0  AM General   DJ Po Vehicle 2WD
# 28426       1984.0  AM General   DJ Po Vehicle 2WD
# 27549       1984.0  AM General    FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587                  Minicompact Cars   Regular                20.0
# 27681                       Two Seaters   Regular                20.0
# 27550       Special Purpose Vehicle 2WD       NaN                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0

# %%
fuel = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=[ 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'], index_col='Vehicle ID')

# %%
fuel.loc[27681, 'Combined MPG (FT1)'] = np.NaN

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                 NaN
# 27550        Regular                17.0

# %%
fuel.sort_values(by=['Make', 'Model']).head()
# Out:
#             Year        Make                Model  \
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
# 1032        1985  AM General  Post Office DJ5 2WD
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD   Regular                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0

# %%
fuel.sort_values('Combined MPG (FT1)', ascending=False).head()
# Out:
#             Year        Make           Model             Class    Fuel Type  \
# Vehicle ID
# 31673       2012  Mitsubishi          i-MiEV   Subcompact Cars  Electricity
# 32278       2012        Ford  Focus Electric      Compact Cars  Electricity
# 32276       2011         BMW        Active E   Subcompact Cars  Electricity
# 30979       2011      Nissan            Leaf      Midsize Cars  Electricity
# 30978       2008        MINI           MiniE  Minicompact Cars  Electricity
#
#             Combined MPG (FT1)
# Vehicle ID
# 31673                    112.0
# 32278                    105.0
# 32276                    102.0
# 30979                     99.0
# 30978                     98.0

# %%
fuel.sort_values(by=['Make', 'Combined MPG (FT1)'], ascending=[True, False]).head()
# Out:
#             Year        Make                Model  \
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 1032        1985  AM General  Post Office DJ5 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD   Regular                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0

# %%
fuel.sort_values('Combined MPG (FT1)', na_position='first').head()
# Out:
#             Year         Make               Model        Class Fuel Type  \
# Vehicle ID
# 27681       1984   Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular
# 32106       2012    Mitsubish                 NaN          NaN       NaN
# 2914        1987  Lamborghini            Countach  Two Seaters   Premium
# 6413        1990  Lamborghini            Countach  Two Seaters   Premium
# 5267        1989  Lamborghini            Countach  Two Seaters   Premium
#
#             Combined MPG (FT1)
# Vehicle ID
# 27681                      NaN
# 32106                      NaN
# 2914                       7.0
# 6413                       7.0
# 5267                       7.0

# %%
fuel.sort_index().head()
# Out:
#             Year        Make               Model        Class Fuel Type  \
# Vehicle ID
# 1           1985  Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular
# 2           1985     Bertone                X1/9  Two Seaters   Regular
# 3           1985   Chevrolet            Corvette  Two Seaters   Regular
# 4           1985   Chevrolet            Corvette  Two Seaters   Regular
# 5           1985      Nissan               300ZX  Two Seaters   Regular
#
#             Combined MPG (FT1)
# Vehicle ID
# 1                         21.0
# 2                         22.0
# 3                         17.0
# 4                         17.0
# 5                         16.0

# %%
fuel = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=[ 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'], index_col='Vehicle ID')

# %%
fuel.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31684 entries, 26587 to 32106
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                31684 non-null  int64
#  1   Make                31684 non-null  object
#  2   Model               31683 non-null  object
#  3   Class               31683 non-null  object
#  4   Fuel Type           31683 non-null  object
#  5   Combined MPG (FT1)  31683 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 8.9 MB

# %%
fuel['Year'] = fuel['Year'].astype('int32')

# %%
fuel.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31684 entries, 26587 to 32106
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                31684 non-null  int32
#  1   Make                31684 non-null  object
#  2   Model               31683 non-null  object
#  3   Class               31683 non-null  object
#  4   Fuel Type           31683 non-null  object
#  5   Combined MPG (FT1)  31683 non-null  float64
# dtypes: float64(1), int32(1), object(4)
# memory usage: 8.8 MB

# %%
fuel['Make'].value_counts()
# Out:
# Chevrolet                           3389
# Ford                                2721
# Dodge                               2361
# GMC                                 2174
# Toyota                              1599
#                                     ...
# Environmental Rsch and Devp Corp       1
# Lambda Control Systems                 1
# CODA Automotive                        1
# Isis Imports Ltd                       1
# Panoz Auto-Development                 1
# Name: Make, Length: 128, dtype: int64

# %%
fuel['Make'] = fuel['Make'].astype('category')

# %%
fuel.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31684 entries, 26587 to 32106
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                31684 non-null  int32
#  1   Make                31684 non-null  category
#  2   Model               31683 non-null  object
#  3   Class               31683 non-null  object
#  4   Fuel Type           31683 non-null  object
#  5   Combined MPG (FT1)  31683 non-null  float64
# dtypes: category(1), float64(1), int32(1), object(3)
# memory usage: 6.9 MB

# %%
fuel['Model'].value_counts()
# Out:
# F150 Pickup 2WD               194
# Truck 2WD                     187
# F150 Pickup 4WD               172
# Ranger Pickup 2WD             169
# Mustang                       156
#                              ...
# 599 SA Aperta                   1
# 940 Turbo                       1
# Range Rover County Classic      1
# 960 Wagon/V90                   1
# Six Door                        1
# Name: Model, Length: 2957, dtype: int64

# %%
fuel['Model'] = fuel['Model'].astype('category')

# %%
fuel['Class'].value_counts()
# Out:
# Compact Cars                    4489
# Subcompact Cars                 4299
# Midsize Cars                    3393
# Standard Pickup Trucks          2354
# Sport Utility Vehicle - 4WD     2034
# Sport Utility Vehicle - 2WD     1598
# Special Purpose Vehicles        1455
# Two Seaters                     1448
# Large Cars                      1351
# Small Station Wagons            1275
# Vans                            1141
# Standard Pickup Trucks 2WD      1043
# Minicompact Cars                 941
# Standard Pickup Trucks 4WD       846
# Midsize-Large Station Wagons     656
# Small Pickup Trucks              538
# Special Purpose Vehicle 2WD      536
# Midsize Station Wagons           492
# Vans, Cargo Type                 397
# Small Pickup Trucks 2WD          365
# Special Purpose Vehicle 4WD      287
# Minivan - 2WD                    278
# Vans, Passenger Type             253
# Small Pickup Trucks 4WD          162
# Minivan - 4WD                     41
# ...

# %%
fuel['Class'] = fuel['Class'].astype('category')

# %%
fuel['Fuel Type'] = fuel['Fuel Type'].astype('category')

# %%
fuel.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31684 entries, 26587 to 32106
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                31684 non-null  int32
#  1   Make                31684 non-null  category
#  2   Model               31683 non-null  category
#  3   Class               31683 non-null  category
#  4   Fuel Type           31683 non-null  category
#  5   Combined MPG (FT1)  31683 non-null  float64
# dtypes: category(4), float64(1), int32(1)
# memory usage: 1.1 MB

# %%
fuel['Combined MPG (FT1)'] = fuel['Combined MPG (FT1)'].astype('float')

# %%
fuel.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31684 entries, 26587 to 32106
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                31684 non-null  int32
#  1   Make                31684 non-null  category
#  2   Model               31683 non-null  category
#  3   Class               31683 non-null  category
#  4   Fuel Type           31683 non-null  category
#  5   Combined MPG (FT1)  31683 non-null  float64
# dtypes: category(4), float64(1), int32(1)
# memory usage: 1.1 MB

# %%
fuel = pd.read_csv('../course-files/fuel.csv', low_memory=False, usecols=[ 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)','Start Stop Technology'], index_col='Vehicle ID')

# %%
list_of_cars = ['Renault', 'Toyota', 'Ford']

# %%
is_in_list = fuel['Make'].isin(list_of_cars)

# %%
fuel[is_in_list].head()
# Out:
#             Year  Make       Model                        Class Fuel Type  \
# Vehicle ID
# 27613       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
# 27616       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
# 27619       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
# 27622       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
# 28472       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
#
#             Combined MPG (FT1) Start Stop Technology
# Vehicle ID
# 27613                     13.0                   NaN
# 27616                     11.0                   NaN
# 27619                     10.0                   NaN
# 27622                     11.0                   NaN
# 28472                     13.0                   NaN

# %%
is_start_stop_defined = fuel['Start Stop Technology'].notnull()

# %%
fuel[is_start_stop_defined].tail()
# Out:
#             Year           Make           Model                        Class  \
# Vehicle ID
# 31926       2012          Lexus         RX 450h  Sport Utility Vehicle - 2WD
# 31971       2012          Lexus     RX 450h AWD  Sport Utility Vehicle - 4WD
# 31395       2012        Lincoln  MKZ Hybrid FWD                 Midsize Cars
# 31799       2012  Mercedes-Benz     S400 Hybrid                   Large Cars
# 31673       2012     Mitsubishi          i-MiEV              Subcompact Cars
#
#               Fuel Type  Combined MPG (FT1) Start Stop Technology
# Vehicle ID
# 31926           Premium                29.0                     Y
# 31971           Premium                28.0                     Y
# 31395           Regular                38.0                     Y
# 31799           Premium                21.0                     Y
# 31673       Electricity               112.0                     N

# %%
start_stop_cars = fuel[fuel['Start Stop Technology'] == 'Y']

# %%
start_stop_cars.head()
# Out:
#             Year    Make    Model         Class Fuel Type  Combined MPG (FT1)  \
# Vehicle ID
# 15606       2000   Honda  Insight   Two Seaters   Regular                53.0
# 16445       2001   Honda  Insight   Two Seaters   Regular                47.0
# 16446       2001   Honda  Insight   Two Seaters   Regular                47.0
# 16447       2001   Honda  Insight   Two Seaters   Regular                53.0
# 16705       2001  Toyota    Prius  Compact Cars   Regular                41.0
#
#            Start Stop Technology
# Vehicle ID
# 15606                          Y
# 16445                          Y
# 16446                          Y
# 16447                          Y
# 16705                          Y

# %%
is_not_start_stop_def = fuel['Start Stop Technology'].isnull()

# %%
fuel[is_not_start_stop_def].head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1) Start Stop Technology
# Vehicle ID
# 26587        Regular                20.0                   NaN
# 27705        Regular                20.0                   NaN
# 26561        Regular                21.0                   NaN
# 27681        Regular                21.0                   NaN
# 27550        Regular                17.0                   NaN

# %%
mpg50_60 = fuel['Combined MPG (FT1)'].between(50, 60)

# %%
mpg50_60.head()
# Out:
# Vehicle ID
# 26587    False
# 27705    False
# 26561    False
# 27681    False
# 27550    False
# Name: Combined MPG (FT1), dtype: bool

# %%
fuel[mpg50_60].head()
# Out:
#             Year       Make              Model                       Class  \
# Vehicle ID
# 30976       1998  Chevrolet       S10 Electric     Small Pickup Trucks 2WD
# 30971       1999       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 30966       2000       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 30967       2000       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 15606       2000      Honda            Insight                 Two Seaters
#
#               Fuel Type  Combined MPG (FT1) Start Stop Technology
# Vehicle ID
# 30976       Electricity                55.0                     N
# 30971       Electricity                58.0                     N
# 30966       Electricity                58.0                     N
# 30967       Electricity                56.0                     N
# 15606           Regular                53.0                     Y

# %%
print('There are ', len(fuel[is_in_list]), ' cars in ', list_of_cars)
print('There are ', len(fuel[is_start_stop_defined]), ' cars where Start/Stop is defined')
print('There are ', len(fuel[mpg50_60]), ' cars with MPG between 50 and 60')
# Out:
# There are  4376  cars in  ['Renault', 'Toyota', 'Ford']
# There are  310  cars where Start/Stop is defined
# There are  13  cars with MPG between 50 and 60
